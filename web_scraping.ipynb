# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime


headers = {
    'authority': 'www.amazon.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9,bn;q=0.8',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Google Chrome";v="102"',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'
}


reviews_url = 'https://www.amazon.com/Intel-i5-12600K-Desktop-Processor-Unlocked/product-reviews/B09FX4D72T/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

len_page = 4


def reviewsHtml(url, len_page):


    soups = []


    for page_no in range(1, len_page + 1):


        params = {
            'ie': 'UTF8',
            'reviewerType': 'all_reviews',
            'filterByStar': 'critical',
            'pageNumber': page_no,
        }


        response = requests.get(url, headers=headers)


        soup = BeautifulSoup(response.text, 'lxml')


        soups.append(soup)

    return soups


def getReviews(html_data):


    data_dicts = []


    boxes = html_data.select('div[data-hook="review"]')
    for box in boxes:

        try:
            name = box.select_one('[class="a-profile-name"]').text.strip()
        except Exception as e:
            name = 'N/A'

        try:
            stars = box.select_one('[data-hook="review-star-rating"]').text.strip().split(' out')[0]
        except Exception as e:
            stars = 'N/A'

        try:
            title = box.select_one('[data-hook="review-title"]').text.strip()
        except Exception as e:
            title = 'N/A'

        try:
            datetime_str = box.select_one('[data-hook="review-date"]').text.strip().split(' on ')[-1]
            date = datetime.strptime(datetime_str, '%B %d, %Y').strftime("%d/%m/%Y")
        except Exception as e:
            date = 'N/A'

        try:
            description = box.select_one('[data-hook="review-body"]').text.strip()
        except Exception as e:
            description = 'N/A'
        data_dict = {
            'Name' : name,
            'Stars' : stars,
            'Title' : title,
            'Date' : date,
            'Description' : description
        }

        data_dicts.append(data_dict)

    return data_dicts

html_datas = reviewsHtml(reviews_url, len_page)

reviews = []

for html_data in html_datas:

    review = getReviews(html_data)

    reviews += review

df_reviews = pd.DataFrame(reviews)

print(df_reviews)

df_reviews.to_csv('reviews.csv', index=False)
# Out:
#                Name Stars                                              Title  \
# 0         torreon49   5.0             5.0 out of 5 stars\nPleasant surprise!
# 1   stephanie steig   5.0                    5.0 out of 5 stars\nWorks great
# 2               Kyl   5.0     5.0 out of 5 stars\nAmazing CPU for thr Price!
# 3          Feng lin   5.0                 5.0 out of 5 stars\nSuperb product
# 4   Amazon Customer   5.0  5.0 out of 5 stars\nImpressive Performance and...
# 5          Sho'Nuff   5.0                     5.0 out of 5 stars\nImpressive
# 6             Manny   5.0  5.0 out of 5 stars\nSuper recommended for the ...
# 7             Kevin   5.0                  5.0 out of 5 stars\nGreat in 2023
# 8           CoolGuy   5.0                          5.0 out of 5 stars\nGREAT
# 9           Nicolas   5.0              5.0 out of 5 stars\nExcelente compra!
# 10        torreon49   5.0             5.0 out of 5 stars\nPleasant surprise!
# 11  stephanie steig   5.0                    5.0 out of 5 stars\nWorks great
# 12              Kyl   5.0     5.0 out of 5 stars\nAmazing CPU for thr Price!
# 13         Feng lin   5.0                 5.0 out of 5 stars\nSuperb product
# 14  Amazon Customer   5.0  5.0 out of 5 stars\nImpressive Performance and...
# 15         Sho'Nuff   5.0                     5.0 out of 5 stars\nImpressive
# 16            Manny   5.0  5.0 out of 5 stars\nSuper recommended for the ...
# 17            Kevin   5.0                  5.0 out of 5 stars\nGreat in 2023
# 18          CoolGuy   5.0                          5.0 out of 5 stars\nGREAT
# 19          Nicolas   5.0              5.0 out of 5 stars\nExcelente compra!
#
#           Date                                        Description
# 0   20/12/2023  Nice CPU. This replaces my old 4790K pc, and w...
# 1   23/05/2024  I’ve played on this for maybe a week or two? T...
# 2   14/04/2024  Upgraded from an i7 8700 to this and its soooo...
# 3   19/05/2024                ble operation, first class product.
# 4   13/05/2024  The 12600K CPU has been an outstanding upgrade...
# 5   12/11/2023  Decided to finally upgrade from my 6 or 7 year...
# 6   27/04/2024  Despite of being an older generation it can pl...
# 7   17/12/2023  Purchased for $150 for Cyber Monday 2023 and i...
# 8   24/06/2024  great cpu i bought it for 125 or 150 on black ...
# 9   09/05/2024  Perú (Español)Si tienes dudas de comprar a tra...
# 10  20/12/2023  Nice CPU. This replaces my old 4790K pc, and w...
# 11  23/05/2024  I’ve played on this for maybe a week or two? T...
# 12  14/04/2024  Upgraded from an i7 8700 to this and its soooo...
# 13  19/05/2024                ble operation, first class product.
# 14  13/05/2024  The 12600K CPU has been an outstanding upgrade...
# 15  12/11/2023  Decided to finally upgrade from my 6 or 7 year...
# 16  27/04/2024  Despite of being an older generation it can pl...
# 17  17/12/2023  Purchased for $150 for Cyber Monday 2023 and i...
# 18  24/06/2024  great cpu i bought it for 125 or 150 on black ...
# 19  09/05/2024  Perú (Español)Si tienes dudas de comprar a tra...
